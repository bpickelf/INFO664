# %% [markdown]
# ## Homework Week 3

# %%
nutrition_meals = [
    {
        "date": "9/5/2026",
        "meal": "Breakfast",
        "calories": 475.2,
        "fat_(g)": 16.7,
        "saturated_fat": 3.9,
        "polyunsaturated_fat": 4.9,
        "monounsaturated_fat": 5.4,
        "trans_fat": 0,
        "cholesterol": 11.6,
        "sodium_(mg)": 236.9,
        "potassium": 799.4,
        "carbohydrates_(g)": 64.6,
        "fiber": 10.1,
        "sugar": 20.9,
        "protein _(g)": 17.3,
        "vitamin_a": 74.3,
        "vitamin c": 17.2,
        "calcium": 39.9,
        "iron": 85.3
    },
    {
        "date": "9/6/2026",
        "meal": "Breakfast",
        "calories": 426.3,
        "fat_(g)": 30.5,
        "saturated_fat": 9.9,
        "polyunsaturated_fat": 1.9,
        "monounsaturated_fat": 3.7,
        "trans_fat": 0,
        "cholesterol": 398.7,
        "sodium_(mg)": 885.4,
        "potassium": 138,
        "carbohydrates_(g)": 16.4,
        "fiber": 2,
        "sugar": 1.1,
        "protein_(g)": 20.3,
        "vitamin_a": 2.7,
        "vitamin_c": 4.7,
        "calcium": 13.6,
        "iron": 11.5
    },
    {
        "date": "9/7/2026",
        "meal": "Breakfast",
        "calories": 397.6,
        "fat_(g)": 27.6,
        "saturated_fat": 4.5,
        "polyunsaturated_fat": 7.8,
        "monounsaturated_fat": 13.3,
        "trans_fat": 0.2,
        "cholesterol": 186,
        "sodium_(mg)": 575.3,
        "potassium": 930.8,
        "carbohydrates_(g)": 28.3,
        "fiber": 3.1,
        "sugar": 4.4,
        "protein_(g)": 10,
        "vitamin_a": 0.3,
        "vitamin_c": 36.4,
        "calcium": 6,
        "iron": 12.3
    },
    {
        "date": "9/8/2026",
        "meal": "Breakfast",
        "calories": 475.2,
        "fat_(g)": 16.7,
        "saturated_fat": 3.9,
        "polyunsaturated_fat": 4.9,
        "monounsaturated_fat": 5.4,
        "trans_fat": 0,
        "cholesterol": 11.6,
        "sodium_(mg)": 236.9,
        "potassium": 799.4,
        "carbohydrates_(g)": 64.6,
        "fiber": 10.1,
        "sugar": 20.9,
        "protein_(g)": 17.3,
        "vitamin_a": 74.3,
        "vitamin_c": 17.2,
        "calcium": 39.9,
        "iron": 85.3
    },
    {
        "date": "9/9/2026",
        "meal": "Breakfast",
        "calories": 408.5,
        "fat_(g)": 16.9,
        "saturated_fat": 3.8,
        "polyunsaturated_fat": 3.7,
        "monounsaturated_fat": 6.3,
        "trans_fat": 0,
        "cholesterol": 392,
        "sodium_(mg)": 487.3,
        "potassium": 286.8,
        "carbohydrates_(g)": 44.5,
        "fiber": 6.1,
        "sugar": 6.1,
        "protein_(g)": 19.4,
        "vitamin_a": 0,
        "vitamin_c": 4.6,
        "calcium": 13.8,
        "iron": 24.1
    },
    {
        "date": "9/10/2026",
        "meal": "Breakfast",
        "calories": 228,
        "fat_(g)": 6.9,
        "saturated_fat": 1.4,
        "polyunsaturated_fat": 2.8,
        "monounsaturated_fat": 1.3,
        "trans_fat": 0,
        "cholesterol": 4.9,
        "sodium_(mg)": 148.8,
        "potassium": 286.8,
        "carbohydrates_(g)": 32,
        "fiber": 6.2,
        "sugar": 2.8,
        "protein_(g)": 10.1,
        "vitamin_a": 69.3,
        "vitamin_c": 0.1,
        "calcium": 33.5,
        "iron": 82.1
    },
    {
        "date": "9/11/2026",
        "meal": "Breakfast",
        "calories": 401,
        "fat_(g)": 16.8,
        "saturated_fat": 3.8,
        "polyunsaturated_fat": 3.7,
        "monounsaturated_fat": 6.3,
        "trans_fat": 0,
        "cholesterol": 392,
        "sodium_(mg)": 486.3,
        "potassium": 213.3,
        "carbohydrates_(g)": 42.7,
        "fiber": 5.8,
        "sugar": 5.3,
        "protein_(g)": 19.1,
        "vitamin_a": 0,
        "vitamin_c": 2.3,
        "calcium": 13,
        "iron": 23.3
    },
    {
        "date": "9/12/2026",
        "meal": "Breakfast",
        "calories": 454,
        "fat_(g)": 25.2,
        "saturated_fat": 7.8,
        "polyunsaturated_fat": 7.4,
        "monounsaturated_fat": 5.6,
        "trans_fat": 0.2,
        "cholesterol": 392,
        "sodium_(mg)": 911.9,
        "potassium": 975.7,
        "carbohydrates_(g)": 26.2,
        "fiber": 2.6,
        "sugar": 4,
        "protein_(g)": 29.4,
        "vitamin_a": 9.4,
        "vitamin_c": 95.6,
        "calcium": 22.7,
        "iron": 15.6
    },

    {
        "date": "9/6/2026",
        "meal": "Dinner",
        "calories": 405.9,
        "fat_(g)": 26.4,
        "saturated_fat": 5.4,
        "polyunsaturated_fat": 4.9,
        "monounsaturated_fat": 12.9,
        "trans_fat": 0,
        "cholesterol": 25,
        "sodium_(mg)": 214,
        "potassium": 1185.5,
        "carbohydrates_(g)": 33.9,
        "fiber": 8.5,
        "sugar": 13.6,
        "protein_(g)": 13.9,
        "vitamin_a": 60.9,
        "vitamin_c": 55.4,
        "calcium": 15.8,
        "iron": 61.7
    },
    {
        "date": "9/7/2026",
        "meal": "Dinner",
        "calories": 603.8,
        "fat_(g)": 20.4,
        "saturated_fat": 9.1,
        "polyunsaturated_fat": 0.1,
        "monounsaturated_fat": 0.1,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 1217.1,
        "potassium": 465.3,
        "carbohydrates_(g)": 91.2,
        "fiber": 3.6,
        "sugar": 8.1,
        "protein_(g)": 13.2,
        "vitamin_a": 0,
        "vitamin_c": 0,
        "calcium": 7.6,
        "iron": 22.6
    },
    {
        "date": "9/8/2026",
        "meal": "Dinner",
        "calories": 257.8,
        "fat_(g)": 9.9,
        "saturated_fat": 2.9,
        "polyunsaturated_fat": 0.8,
        "monounsaturated_fat": 5.6,
        "trans_fat": 0.2,
        "cholesterol": 56.1,
        "sodium_(mg)": 1987.7,
        "potassium": 866.1,
        "carbohydrates_(g)": 17.7,
        "fiber": 6.2,
        "sugar": 7.5,
        "protein_(g)": 27.6,
        "vitamin_a": 1.8,
        "vitamin_c": 139.8,
        "calcium": 21.7,
        "iron": 27.4
    },
    {
        "date": "9/9/2026",
        "meal": "Dinner",
        "calories": 441,
        "fat_(g)": 29.2,
        "saturated_fat": 8.6,
        "polyunsaturated_fat": 6.2,
        "monounsaturated_fat": 13.4,
        "trans_fat": 0,
        "cholesterol": 245,
        "sodium_(mg)": 707,
        "potassium": 367.5,
        "carbohydrates_(g)": 0,
        "fiber": 0,
        "sugar": 0,
        "protein_(g)": 41.3,
        "vitamin_a": 0,
        "vitamin_c": 0,
        "calcium": 3.1,
        "iron": 8.1
    },
    {
        "date": "9/10/2026",
        "meal": "Dinner",
        "calories": 299.3,
        "fat_(g)": 7.9,
        "saturated_fat": 1,
        "polyunsaturated_fat": 3.1,
        "monounsaturated_fat": 1.3,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 410,
        "potassium": 750.7,
        "carbohydrates_(g)": 41.7,
        "fiber": 4.2,
        "sugar": 1.8,
        "protein_(g)": 12.9,
        "vitamin_a": 185.1,
        "vitamin_c": 118.9,
        "calcium": 28,
        "iron": 29
    },
    {
        "date": "9/11/2026",
        "meal": "Dinner",
        "calories": 280,
        "fat_(g)": 2,
        "saturated_fat": 0,
        "polyunsaturated_fat": 0,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 680,
        "potassium": 1380,
        "carbohydrates_(g)": 62,
        "fiber": 20,
        "sugar": 6,
        "protein_(g)": 16,
        "vitamin_a": 0,
        "vitamin_c": 0,
        "calcium": 8,
        "iron": 28.9
    },
    {
        "date": "9/12/2026",
        "meal": "Dinner",
        "calories": 380,
        "fat_(g)": 14.6,
        "saturated_fat": 6,
        "polyunsaturated_fat": 0,
        "monounsaturated_fat": 2,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 750,
        "potassium": 292,
        "carbohydrates_(g)": 12,
        "fiber": 4,
        "sugar": 4,
        "protein_(g)": 52,
        "vitamin_a": 30,
        "vitamin_c": 12,
        "calcium": 18,
        "iron": 10
    },

    {
        "date": "9/7/2026",
        "meal": "Lunch",
        "calories": 180,
        "fat_(g)": 7,
        "saturated_fat": 1,
        "polyunsaturated_fat": 0,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 190,
        "potassium": 610,
        "carbohydrates_(g)": 27,
        "fiber": 2,
        "sugar": 1,
        "protein_(g)": 3,
        "vitamin_a": 0,
        "vitamin_c": 10,
        "calcium": 10,
        "iron": 1
    },
    {
        "date": "9/8/2026",
        "meal": "Lunch",
        "calories": 299.3,
        "fat_(g)": 7.9,
        "saturated_fat": 1,
        "polyunsaturated_fat": 3.1,
        "monounsaturated_fat": 1.3,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 410,
        "potassium": 750.7,
        "carbohydrates_(g)": 41.7,
        "fiber": 4.2,
        "sugar": 1.8,
        "protein_(g)": 12.9,
        "vitamin_a": 185.1,
        "vitamin_c": 118.9,
        "calcium": 28,
        "iron": 29
    },
    {
        "date": "9/9/2026",
        "meal": "Lunch",
        "calories": 299.3,
        "fat_(g)": 7.9,
        "saturated_fat": 1,
        "polyunsaturated_fat": 3.1,
        "monounsaturated_fat": 1.3,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 410,
        "potassium": 750.7,
        "carbohydrates_(g)": 41.7,
        "fiber": 4.2,
        "sugar": 1.8,
        "protein_(g)": 12.9,
        "vitamin_a": 185.1,
        "vitamin_c": 118.9,
        "calcium": 28,
        "iron": 29
    },
    {
        "date": "9/10/2026",
        "meal": "Lunch",
        "calories": 524.2,
        "fat_(g)": 22.4,
        "saturated_fat": 9.9,
        "polyunsaturated_fat": 2.9,
        "monounsaturated_fat": 6.5,
        "trans_fat": 0,
        "cholesterol": 404.9,
        "sodium_(mg)": 658.5,
        "potassium": 253.6,
        "carbohydrates_(g)": 55.7,
        "fiber": 1.7,
        "sugar": 9.4,
        "protein_(g)": 23.8,
        "vitamin_a": 7.1,
        "vitamin_c": 0,
        "calcium": 13.3,
        "iron": 30.5
    },
    {
        "date": "9/12/2026",
        "meal": "Lunch",
        "calories": 172.6,
        "fat_(g)": 7.2,
        "saturated_fat": 1,
        "polyunsaturated_fat": 0.1,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 779.8,
        "potassium": 247.7,
        "carbohydrates_(g)": 23.5,
        "fiber": 2.7,
        "sugar": 3.7,
        "protein_(g)": 3.4,
        "vitamin_a": 1.5,
        "vitamin_c": 3,
        "calcium": 2.7,
        "iron": 4.2
    },

    {
        "date": "9/5/2026",
        "meal": "Snacks",
        "calories": 154.1,
        "fat_(g)": 5.9,
        "saturated_fat": 2.3,
        "polyunsaturated_fat": 0.1,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 14.8,
        "sodium_(mg)": 97.1,
        "potassium": 364.7,
        "carbohydrates_(g)": 15.4,
        "fiber": 0,
        "sugar": 4.4,
        "protein_(g)": 10.7,
        "vitamin_a": 0,
        "vitamin_c": 0.2,
        "calcium": 33.7,
        "iron": 0.4
    },
    {
        "date": "9/7/2026",
        "meal": "Snacks",
        "calories": 16.1,
        "fat_(g)": 0.2,
        "saturated_fat": 0,
        "polyunsaturated_fat": 0,
        "monounsaturated_fat": 0.1,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 22.1,
        "potassium": 284,
        "carbohydrates_(g)": 2,
        "fiber": 0.3,
        "sugar": 0.9,
        "protein_(g)": 1,
        "vitamin_a": 0,
        "vitamin_c": 0,
        "calcium": 5.4,
        "iron": 0.5
    },
    {
        "date": "9/8/2026",
        "meal": "Snacks",
        "calories": 200.4,
        "fat_(g)": 6.4,
        "saturated_fat": 0.9,
        "polyunsaturated_fat": 0.1,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 5,
        "sodium_(mg)": 103.4,
        "potassium": 274,
        "carbohydrates_(g)": 22.5,
        "fiber": 0,
        "sugar": 1,
        "protein_(g)": 17.1,
        "vitamin_a": 0,
        "vitamin_c": 0.2,
        "calcium": 36.6,
        "iron": 0.4
    },
    {
        "date": "9/9/2026",
        "meal": "Snacks",
        "calories": 301.7,
        "fat_(g)": 11.5,
        "saturated_fat": 2.3,
        "polyunsaturated_fat": 2.1,
        "monounsaturated_fat": 3.8,
        "trans_fat": 0,
        "cholesterol": 5,
        "sodium_(mg)": 492.3,
        "potassium": 515.1,
        "carbohydrates_(g)": 35.4,
        "fiber": 1.7,
        "sugar": 1.2,
        "protein_(g)": 17.9,
        "vitamin_a": 0.1,
        "vitamin_c": 5.8,
        "calcium": 37.8,
        "iron": 3.1
    },
    {
        "date": "9/11/2026",
        "meal": "Snacks",
        "calories": 80.4,
        "fat_(g)": 1.4,
        "saturated_fat": 0.9,
        "polyunsaturated_fat": 0.1,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 5,
        "sodium_(mg)": 103.4,
        "potassium": 274,
        "carbohydrates_(g)": 2.5,
        "fiber": 0,
        "sugar": 1,
        "protein_(g)": 15.1,
        "vitamin_a": 0,
        "vitamin_c": 0.2,
        "calcium": 36.6,
        "iron": 0.4
    },
    {
        "date": "9/12/2026",
        "meal": "Snacks",
        "calories": 832.4,
        "fat_(g)": 36.4,
        "saturated_fat": 7.3,
        "polyunsaturated_fat": 14.3,
        "monounsaturated_fat": 12.2,
        "trans_fat": 0,
        "cholesterol": 99,
        "sodium_(mg)": 663.4,
        "potassium": 378,
        "carbohydrates_(g)": 107.5,
        "fiber": 1.8,
        "sugar": 80,
        "protein_(g)": 19.9,
        "vitamin_a": 0,
        "vitamin_c": 0.9,
        "calcium": 50.8,
        "iron": 10.4
    }
]
steps_data = [
    {
        "date": "8/29/2026",
        "steps": 9055,
        "distance": 3.8,
        "metric": "miles"
    },
    {
        "date": "8/30/2026",
        "steps": 1454,
        "distance": 0.62,
        "metric": "miles"
    },
    {
        "date": "8/31/2026",
        "steps": 11112,
        "distance": 4.6,
        "metric": "miles"
    },
    {
        "date": "9/1/2026",
        "steps": 12338,
        "distance": 4.9,
        "metric": "miles"
    },
    {
        "date": "9/2/2026",
        "steps": 16127,
        "distance": 6.7,
        "metric": "miles"
    },
    {
        "date": "9/3/2026",
        "steps": 13201,
        "distance": 5.5,
        "metric": "miles"
    },
    {
        "date": "9/4/2026",
        "steps": 12674,
        "distance": 5.1,
        "metric": "miles"
    },
    {
        "date": "9/5/2026",
        "steps": 2873,
        "distance": 1.1,
        "metric": "miles"
    },
    {
        "date": "9/6/2026",
        "steps": 3890,
        "distance": 1.7,
        "metric": "miles"
    },
    {
        "date": "9/7/2026",
        "steps": 2032,
        "distance": 0.96,
        "metric": "miles"
    },
    {
        "date": "9/8/2026",
        "steps": 12381,
        "distance": 5,
        "metric": "miles"
    },
    {
        "date": "9/9/2026",
        "steps": 12513,
        "distance": 4.9,
        "metric": "miles"
    },
    {
        "date": "9/10/2026",
        "steps": 13638,
        "distance": 5.6,
        "metric": "miles"
    },
    {
        "date": "9/11/2026",
        "steps": 95,
        "distance": 0.04,
        "metric": "miles"
    },
    {
        "date": "9/12/2026",
        "steps": 2958,
        "distance": 1.2,
        "metric": "miles"
    }
]

# %%
print(nutrition_meals)
# Out:
# [{'date': '9/5/2026', 'meal': 'Breakfast', 'calories': 475.2, 'fat_(g)': 16.7, 'saturated_fat': 3.9, 'polyunsaturated_fat': 4.9, 'monounsaturated_fat': 5.4, 'trans_fat': 0, 'cholesterol': 11.6, 'sodium_(mg)': 236.9, 'potassium': 799.4, 'carbohydrates_(g)': 64.6, 'fiber': 10.1, 'sugar': 20.9, 'protein _(g)': 17.3, 'vitamin_a': 74.3, 'vitamin c': 17.2, 'calcium': 39.9, 'iron': 85.3}, {'date': '9/6/2026', 'meal': 'Breakfast', 'calories': 426.3, 'fat_(g)': 30.5, 'saturated_fat': 9.9, 'polyunsaturated_fat': 1.9, 'monounsaturated_fat': 3.7, 'trans_fat': 0, 'cholesterol': 398.7, 'sodium_(mg)': 885.4, 'potassium': 138, 'carbohydrates_(g)': 16.4, 'fiber': 2, 'sugar': 1.1, 'protein_(g)': 20.3, 'vitamin_a': 2.7, 'vitamin_c': 4.7, 'calcium': 13.6, 'iron': 11.5}, {'date': '9/7/2026', 'meal': 'Breakfast', 'calories': 397.6, 'fat_(g)': 27.6, 'saturated_fat': 4.5, 'polyunsaturated_fat': 7.8, 'monounsaturated_fat': 13.3, 'trans_fat': 0.2, 'cholesterol': 186, 'sodium_(mg)': 575.3, 'potassium': 930.8, 
# ...

# %%
sort_nutrition_meals = sorted(
    nutrition_meals,
    key=lambda meal: meal["calories"]
)

print(sort_nutrition_meals)
# Out:
# [{'date': '9/7/2026', 'meal': 'Snacks', 'calories': 16.1, 'fat_(g)': 0.2, 'saturated_fat': 0, 'polyunsaturated_fat': 0, 'monounsaturated_fat': 0.1, 'trans_fat': 0, 'cholesterol': 0, 'sodium_(mg)': 22.1, 'potassium': 284, 'carbohydrates_(g)': 2, 'fiber': 0.3, 'sugar': 0.9, 'protein_(g)': 1, 'vitamin_a': 0, 'vitamin_c': 0, 'calcium': 5.4, 'iron': 0.5}, {'date': '9/11/2026', 'meal': 'Snacks', 'calories': 80.4, 'fat_(g)': 1.4, 'saturated_fat': 0.9, 'polyunsaturated_fat': 0.1, 'monounsaturated_fat': 0, 'trans_fat': 0, 'cholesterol': 5, 'sodium_(mg)': 103.4, 'potassium': 274, 'carbohydrates_(g)': 2.5, 'fiber': 0, 'sugar': 1, 'protein_(g)': 15.1, 'vitamin_a': 0, 'vitamin_c': 0.2, 'calcium': 36.6, 'iron': 0.4}, {'date': '9/5/2026', 'meal': 'Snacks', 'calories': 154.1, 'fat_(g)': 5.9, 'saturated_fat': 2.3, 'polyunsaturated_fat': 0.1, 'monounsaturated_fat': 0, 'trans_fat': 0, 'cholesterol': 14.8, 'sodium_(mg)': 97.1, 'potassium': 364.7, 'carbohydrates_(g)': 15.4, 'fiber': 0, 'sugar': 4.4, 'pro
# ...

# %%
print(steps_data)
# Out:
# [{'date': '8/29/2026', 'steps': 9055, 'distance': 3.8, 'metric': 'miles'}, {'date': '8/30/2026', 'steps': 1454, 'distance': 0.62, 'metric': 'miles'}, {'date': '8/31/2026', 'steps': 11112, 'distance': 4.6, 'metric': 'miles'}, {'date': '9/1/2026', 'steps': 12338, 'distance': 4.9, 'metric': 'miles'}, {'date': '9/2/2026', 'steps': 16127, 'distance': 6.7, 'metric': 'miles'}, {'date': '9/3/2026', 'steps': 13201, 'distance': 5.5, 'metric': 'miles'}, {'date': '9/4/2026', 'steps': 12674, 'distance': 5.1, 'metric': 'miles'}, {'date': '9/5/2026', 'steps': 2873, 'distance': 1.1, 'metric': 'miles'}, {'date': '9/6/2026', 'steps': 3890, 'distance': 1.7, 'metric': 'miles'}, {'date': '9/7/2026', 'steps': 2032, 'distance': 0.96, 'metric': 'miles'}, {'date': '9/8/2026', 'steps': 12381, 'distance': 5, 'metric': 'miles'}, {'date': '9/9/2026', 'steps': 12513, 'distance': 4.9, 'metric': 'miles'}, {'date': '9/10/2026', 'steps': 13638, 'distance': 5.6, 'metric': 'miles'}, {'date': '9/11/2026', 'steps': 95, '
# ...

# %%
sort_steps_data = sorted(
    steps_data,
    key=lambda steps: steps["steps"], reverse=True)


print(sort_steps_data)
# Out:
# [{'date': '9/2/2026', 'steps': 16127, 'distance': 6.7, 'metric': 'miles'}, {'date': '9/10/2026', 'steps': 13638, 'distance': 5.6, 'metric': 'miles'}, {'date': '9/3/2026', 'steps': 13201, 'distance': 5.5, 'metric': 'miles'}, {'date': '9/4/2026', 'steps': 12674, 'distance': 5.1, 'metric': 'miles'}, {'date': '9/9/2026', 'steps': 12513, 'distance': 4.9, 'metric': 'miles'}, {'date': '9/8/2026', 'steps': 12381, 'distance': 5, 'metric': 'miles'}, {'date': '9/1/2026', 'steps': 12338, 'distance': 4.9, 'metric': 'miles'}, {'date': '8/31/2026', 'steps': 11112, 'distance': 4.6, 'metric': 'miles'}, {'date': '8/29/2026', 'steps': 9055, 'distance': 3.8, 'metric': 'miles'}, {'date': '9/6/2026', 'steps': 3890, 'distance': 1.7, 'metric': 'miles'}, {'date': '9/12/2026', 'steps': 2958, 'distance': 1.2, 'metric': 'miles'}, {'date': '9/5/2026', 'steps': 2873, 'distance': 1.1, 'metric': 'miles'}, {'date': '9/7/2026', 'steps': 2032, 'distance': 0.96, 'metric': 'miles'}, {'date': '8/30/2026', 'steps': 1454, 
# ...

# %%
new_meal= {
        "date": "9/13/2026",
        "meal": "Breakfast",
        "calories": 280.0,
        "fat_(g)": 2.0,
        "saturated_fat": 0,
        "polyunsaturated_fat": 0,
        "monounsaturated_fat": 0,
        "trans_fat": 0,
        "cholesterol": 0,
        "sodium_(mg)": 680.0,
        "potassium": 1380.0,
        "carbohydrates_(g)": 62.0,
        "fiber": 20.0,
        "sugar": 6.0,
        "protein_(g)": 16.0,
        "vitamin_a": 0,
        "vitamin_c": 0,
        "calcium": 8.0,
        "iron": 28.9
    }

# %%
nutrition_meals.append(new_meal)
print(
